# %% [markdown]
# <a href="https://colab.research.google.com/github/Jordano-Jackson/2023mech/blob/main/Copy_of_main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world!")
# Out:
# hello world!
